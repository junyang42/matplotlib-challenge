# %%
# Observations:

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
file1 = pd.read_csv(mouse_drug_data_to_load)
file2 = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
file_new = pd.merge(file1, file2, on="Mouse ID")

# Display the data table for preview
file_new.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
groupby_file = file_new.groupby(["Drug", "Timepoint"])
groupby_file_mean = groupby_file["Tumor Volume (mm3)"].mean()
# Convert to DataFrame
summary_data = pd.DataFrame(groupby_file_mean)
summary_data_mean = summary_data.reset_index()
# Preview DataFrame
summary_data_mean
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
standard_error = groupby_file["Tumor Volume (mm3)"].sem()
# Convert to DataFrame
summary_data_std_error = pd.DataFrame(standard_error)
summary_data_std_error_new = summary_data_std_error.reset_index()
# Preview DataFrame
summary_data_std_error_new
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
summary_pivot = summary_data_mean.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")
# Preview that Reformatting worked
summary_pivot
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
std_error_pivot = summary_data_std_error_new.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")
std_error_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
target_table = summary_pivot[["Capomulin","Infubinol","Ketapril","Placebo"]]
std_error_table = std_error_pivot[["Capomulin","Infubinol","Ketapril","Placebo"]]
std_error_table
# Out:
# Drug       Capomulin  Infubinol  Ketapril   Placebo
# Timepoint
# 0           0.000000   0.000000  0.000000  0.000000
# 5           0.448593   0.235102  0.264819  0.218091
# 10          0.702684   0.282346  0.357421  0.402064
# 15          0.838617   0.357705  0.580268  0.614461
# 20          0.909731   0.476210  0.726484  0.839609
# 25          0.881642   0.550315  0.755413  1.034872
# 30          0.934460   0.631061  0.934121  1.218231
# 35          1.052241   0.984155  1.127867  1.287481
# 40          1.223608   1.055220  1.158449  1.370634
# 45          1.223977   1.144427  1.453186  1.351726

# %%
# Generate the Plot (with Error Bars)
fig,ax = plt.subplots(figsize=(8,6))
# set title and labels
plt.title("Tumor Response to Treatment") 
ax.set_ylabel("Tumor Volume (mm3)")
ax.set_xlabel("Time (Days)")
# set range and ticks for x/y axis
max_of_column = target_table.max()
y_max = int(max_of_column.max())
min_of_column = target_table.min()
y_min = int(min_of_column.min())

ax.set_ylim(y_min - 2 ,y_max + 2, 10)                    
ax.set_yticks(range(y_min - 1,y_max + 5, 5))
ax.set_xlim(target_table.index.values.min() - 1, target_table.index.values.max() + 1)                    
ax.set_xticks(range(target_table.index.values.min(), target_table.index.values.max() + 5, 5));
 
format_list = ["o:","^:","s:","d:"]
color_list = ["r","b","g","black"]
drug_list = ["Capomulin","Infubinol","Ketapril","Placebo"]
a = 0

for drug in drug_list:
    ax.errorbar(list(target_table.index.values), target_table[drug], std_error_table[drug],\
                color=color_list[a], fmt=format_list[a])
    a = a + 1
    
# Save the Figure
plt.legend(['Capomulin', 'Infubinol', 'Ketapril', 'Placebo'],loc='best') 
plt.grid(True)
plt.savefig('Tumor_Response_to_Treatment.png')
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
groupby_file_mean2 = groupby_file["Metastatic Sites"].mean()
# Convert to DataFrame
summary_data2 = pd.DataFrame(groupby_file_mean2)
summary_data_mean2 = summary_data2.reset_index()
# Preview DataFrame
summary_data_mean2
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# ..        ...        ...               ...
# 95  Zoniferol         25          1.687500
# 96  Zoniferol         30          1.933333
# 97  Zoniferol         35          2.285714
# 98  Zoniferol         40          2.785714
# 99  Zoniferol         45          3.071429
#
# [100 rows x 3 columns]

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
standard_error2 = groupby_file["Metastatic Sites"].sem()
# Convert to DataFrame
summary_data_std_error2 = pd.DataFrame(standard_error2)
# Preview DataFrame
summary_data_std_error2 = summary_data_std_error2.reset_index()
summary_data_std_error2
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
summary_pivot2 = summary_data_mean2.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")
# Preview that Reformatting worked
summary_pivot2
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
std_error_pivot2 = summary_data_std_error2.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")
std_error_pivot2
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
target_table2 = summary_pivot2[["Capomulin","Infubinol","Ketapril","Placebo"]]
std_error_table2 = std_error_pivot2[["Capomulin","Infubinol","Ketapril","Placebo"]]
std_error_table2
# Out:
# Drug       Capomulin  Infubinol  Ketapril   Placebo
# Timepoint
# 0           0.000000   0.000000  0.000000  0.000000
# 5           0.074833   0.091652  0.098100  0.100947
# 10          0.125433   0.159364  0.142018  0.115261
# 15          0.132048   0.194015  0.191381  0.190221
# 20          0.161621   0.234801  0.236680  0.234064
# 25          0.181818   0.265753  0.288275  0.263888
# 30          0.172944   0.227823  0.347467  0.300264
# 35          0.169496   0.224733  0.361418  0.341412
# 40          0.175610   0.314466  0.315725  0.297294
# 45          0.202591   0.309320  0.278722  0.304240

# %%
# Generate the Plot (with Error Bars)
fig,ax = plt.subplots(figsize=(8,6))
# set title and labels
plt.title("Metastatic Spread During Treatment") 
ax.set_ylabel("Met. Sites")
ax.set_xlabel("Time (Days)")
# set range and ticks for x/y axis
max_of_column2 = target_table2.max()
y_max2 = int(max_of_column2.max())
min_of_column2 = target_table2.min()
y_min2 = int(min_of_column2.min())


ax.set_ylim(y_min2 - 1 ,y_max2 + 1)                    
ax.set_yticks(range(y_min2 - 1,y_max2 + 1, 1))
ax.set_xlim(target_table2.index.values.min() - 1, target_table2.index.values.max() + 1)                    
ax.set_xticks(range(target_table2.index.values.min(), target_table2.index.values.max() + 5, 5));
 
format_list = ["o:","^:","s:","d:"]
color_list = ["r","b","g","k"]
drug_list = ["Capomulin","Infubinol","Ketapril","Placebo"]
a = 0

for drug in drug_list:
    ax.errorbar(list(target_table2.index.values), target_table2[drug], std_error_table2[drug],\
                color=color_list[a], fmt=format_list[a])
    a = a + 1
    
# Save the Figure
plt.legend(['Capomulin', 'Infubinol', 'Ketapril', 'Placebo'],loc='Best') 
plt.grid(True)
plt.savefig('Metastatic Spread During Treatment.png')
# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
groupby_file.head()
mice_count = groupby_file["Mouse ID"].count()
mice_count
# Out:
# Drug       Timepoint
# Capomulin  0            25
#            5            25
#            10           25
#            15           24
#            20           23
#                         ..
# Zoniferol  25           16
#            30           15
#            35           14
#            40           14
#            45           14
# Name: Mouse ID, Length: 100, dtype: int64

# %%
# Convert to DataFrame
mice_count_data = pd.DataFrame(mice_count)
mice_count_data = mice_count_data.reset_index()
mice_count_data = mice_count_data.rename(columns={"Mouse ID":"Mice Count"})
mice_count_data
# Out:
#          Drug  Timepoint  Mice Count
# 0   Capomulin          0          25
# 1   Capomulin          5          25
# 2   Capomulin         10          25
# 3   Capomulin         15          24
# 4   Capomulin         20          23
# ..        ...        ...         ...
# 95  Zoniferol         25          16
# 96  Zoniferol         30          15
# 97  Zoniferol         35          14
# 98  Zoniferol         40          14
# 99  Zoniferol         45          14
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
summary_pivot3 = mice_count_data.pivot(index="Timepoint", columns="Drug", values="Mice Count")
# Preview the Data Frame
summary_pivot3
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
target_table3 = summary_pivot3[["Capomulin","Infubinol","Ketapril","Placebo"]]
target_table3
# Out:
# Drug       Capomulin  Infubinol  Ketapril  Placebo
# Timepoint
# 0                 25         25        25       25
# 5                 25         25        23       24
# 10                25         21        22       24
# 15                24         21        19       20
# 20                23         20        19       19
# 25                22         18        19       17
# 30                22         17        18       15
# 35                22         12        17       14
# 40                21         10        15       12
# 45                21          9        11       11

# %%
# ax.scatter?

# %%
# Generate the Plot (Accounting for percentages)

fig,ax = plt.subplots(figsize=(8,6))
# set title and labels
plt.title("Survival During Treatment") 
ax.set_ylabel("Survival Rate(%)")
ax.set_xlabel("Time (Days)")
# set range and ticks for x/y axis

#ax.set_ylim(0, 100 + 5)                    
#ax.set_yticks(range(0, 110, 10))
ax.set_xlim(target_table3.index.values.min() - 1, target_table3.index.values.max() + 1)                    
ax.set_xticks(range(target_table3.index.values.min(), target_table3.index.values.max() + 5, 5));
 
format_list = ["o","^","s","d"]
color_list = ["r","b","g","k"]
drug_list = ["Capomulin","Infubinol","Ketapril","Placebo"]
a = 0

for drug in drug_list:
    ax.plot(list(target_table3.index.values), target_table3[drug]*100/(target_table3[drug].max() ),\
               color=color_list[a], marker=format_list[a],linestyle='dashed')
    a = a + 1
    
# Save the Figure
plt.legend(['Capomulin', 'Infubinol', 'Ketapril', 'Placebo'],loc='best') 
plt.grid(True)
plt.savefig('Survival During Treatment.png')
# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
# summary_pivot

# %%
percent_change = summary_pivot.diff(periods=1)
percent_change
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0                NaN       NaN        NaN       NaN       NaN       NaN
# 5          -0.733914  1.503051   2.062001  2.389175  1.796098  2.125589
# 10         -1.181796  1.782074   2.341908  2.193094  1.898112  2.297740
# 15         -1.019973  1.808930   1.892488  2.817705  2.238809  1.936412
# 20         -1.347992  2.062994   1.901294  2.520961  2.711069  3.004675
# 25         -0.776797  2.130626   2.517561  2.758047  3.087880  3.118157
# 30         -1.170189  2.481843   2.584145  3.315525  2.827541  2.326489
# 35         -0.952500  2.058031   2.443064  2.377179  3.125578  2.611552
# 40         -0.858838  2.640348   2.420363  2.696894  2.915667  2.632060
# 45         -0.721887  2.664526   2.592738  4.594377  3.664752  3.031407
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0               NaN       NaN       NaN        NaN
# ...

# %%
total_percent_change = percent_change.sum()*100/45  # since the first value of all columns equals to 45
# Display the data to confirm
total_percent_change
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# adjust the results
target_list = total_percent_change.round(2)
target_table4 = pd.DataFrame(target_list, columns={"total_percent_change"})
# target_table4

# %%
# Store all Relevant Percent Changes into a Tuple
x_axia = drug_list
y_axis = [target_table4.loc[value, "total_percent_change"] for value in drug_list ]
# y_axis

# %%
fig,ax = plt.subplots(figsize=(8,6))

# Splice the data between passing and failing drugs
bar_color = ['r' if i > 0 else 'g' for i in y_axis] 

# Orient widths. Add labels, tick marks, etc. 
plt.ylabel('% Tumor Volumn Change')
plt.title('Tumor Change Over 45 Days Treatment')

# setup text inside bar
x_values = [0,1,2,3]
percent_list = [f'{int(i)}%' for i in y_axis]
for i in range(len(drug_list)):
    y_list = [4 if j > 0 else -4 for j in y_axis]
    plt.text(x = x_values[i]-0.7, y =y_list[i] , 
    s = percent_list[i],                         
    size = 10)          
    
# Call functions to implement the function calls
ax.bar(x_axia, y_axis, align='edge',width=-1, alpha=0.5, color=bar_color)

# Save the Figure
plt.grid(True)
fig.savefig("Tumor-Chang.png")

# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
